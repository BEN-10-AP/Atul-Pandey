# %% [markdown]
# <a href="https://colab.research.google.com/github/BEN-10-AP/Atul-Pandey/blob/master/ANN%20regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Load data from CSV file
data = pd.read_csv('input_data.csv')

data.head(5)
# Split data into input and output variables
X = data[['time', 'current density', 'Temperature']].values
y = data['Voltage '].values

# Define model architecture
model = Sequential()
model.add(Dense(32, activation='relu', input_dim=3))
model.add(Dense(1))

# Compile model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train model
model.fit(X, y, epochs=100, batch_size=32)

# Evaluate model
loss = model.evaluate(X, y)
print('Loss:', loss)
# Make predictions
predictions = model.predict(X)

inputs = np.array([[0.90775,	-10,	273]])

# Make prediction using the model
output = model.predict(inputs)

# Print output
print("Output:", output[0][0])
# Out:
# Epoch 1/100
# 102/102 [==============================] - 1s 2ms/step - loss: 810.3323
# Epoch 2/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.9080
# Epoch 3/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1703
# Epoch 4/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.1158
# Epoch 5/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.0961
# Epoch 6/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.0757
# Epoch 7/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.0588
# Epoch 8/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.0463
# Epoch 9/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.0372
# Epoch 10/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.0314
# Epoch 11/100
# 102/102 [==============================] - 0s 2ms/step - loss: 0.0276
# Epoch 12/100
# ...
